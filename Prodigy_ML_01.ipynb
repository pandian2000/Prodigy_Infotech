# %% [markdown]
# ![Green%20Minimalist%20Organic%20Notion%20Header%20%284%29%20(1).jpg](attachment:Green%20Minimalist%20Organic%20Notion%20Header%20%284%29%20(1).jpg)

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import statistics

# %%
d1=pd.read_csv(r"C:\Users\ADMIN\Desktop\Prodigy infotech\train.csv")
d1.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
d1.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
d1.describe(include='O')
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1460         1460       1460  ...       1379         1379
# unique         3           25          9  ...          6            3
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1382          225       1260  ...        870          605
#
#        GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# count        1379       1379       1460      7    281          54     1460
# unique          5          5          3      3      4           4        9
# ...

# %% [markdown]
# ### Null value treatment

# %%
d1.isnull().sum()[d1.isnull().sum()!=0]/d1.shape[0]*100
# Out:
# LotFrontage     17.739726
# Alley           93.767123
# MasVnrType       0.547945
# MasVnrArea       0.547945
# BsmtQual         2.534247
# BsmtCond         2.534247
# BsmtExposure     2.602740
# BsmtFinType1     2.534247
# BsmtFinType2     2.602740
# Electrical       0.068493
# FireplaceQu     47.260274
# GarageType       5.547945
# GarageYrBlt      5.547945
# GarageFinish     5.547945
# GarageQual       5.547945
# GarageCond       5.547945
# PoolQC          99.520548
# Fence           80.753425
# MiscFeature     96.301370
# dtype: float64

# %% [markdown]
# above results indicate the percentage of null values in the variable.I am dropping the columns having null values above 50%

# %%
d1.drop(columns=['MiscFeature','Fence','PoolQC','Alley'],inplace=True)

# %%
d1.shape
# Out:
# (1460, 77)

# %% [markdown]
# After dropping 4 columns our dataset now have 77 columns.Next I am goin to impute the null values with meanmedian for numerical variable and mode for categorical variable.

# %%
d1.select_dtypes(include=np.number).isnull().sum()[d1.select_dtypes(include=np.number).isnull().sum()!=0]
# Out:
# LotFrontage    259
# MasVnrArea       8
# GarageYrBlt     81
# dtype: int64

# %%
d1['LotFrontage'].fillna(d1['LotFrontage'].median(),inplace=True)

# %%
d1['MasVnrArea'].fillna(d1['MasVnrArea'].median(),inplace=True)

# %%
d1['GarageYrBlt'].fillna(d1['GarageYrBlt'].median(),inplace=True)

# %%
d1.select_dtypes(include=np.number).isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# We have all null values in the numerical variable

# %%
d1.select_dtypes(include='O').isnull().sum()[d1.select_dtypes(include='O').isnull().sum()!=0]
# Out:
# MasVnrType        8
# BsmtQual         37
# BsmtCond         37
# BsmtExposure     38
# BsmtFinType1     37
# BsmtFinType2     38
# Electrical        1
# FireplaceQu     690
# GarageType       81
# GarageFinish     81
# GarageQual       81
# GarageCond       81
# dtype: int64

# %%
d1['MasVnrType'].fillna(d1['MasVnrType'].mode()[0],inplace=True)

# %%
d1['BsmtQual'].fillna(d1['BsmtQual'].mode()[0],inplace=True)

# %%
d1['BsmtCond'].fillna(d1['BsmtCond'].mode()[0],inplace=True)

# %%
d1['BsmtExposure'].fillna(d1['BsmtExposure'].mode()[0],inplace=True)

# %%
d1['BsmtFinType1'].fillna(d1['BsmtFinType1'].mode()[0],inplace=True)

# %%
d1['BsmtFinType2'].fillna(d1['BsmtFinType2'].mode()[0],inplace=True)

# %%
d1['Electrical'].fillna(d1['Electrical'].mode()[0],inplace=True)

# %%
d1['FireplaceQu'].fillna(d1['FireplaceQu'].mode()[0],inplace=True)

# %%
d1['GarageType'].fillna(d1['GarageType'].mode()[0],inplace=True)

# %%
d1['GarageFinish'].fillna(d1['GarageFinish'].mode()[0],inplace=True)

# %%
d1['GarageQual'].fillna(d1['GarageQual'].mode()[0],inplace=True)

# %%
d1['GarageCond'].fillna(d1['GarageCond'].mode()[0],inplace=True)

# %%
d1.select_dtypes(include='O').isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Outlier Treatment

# %%
q1=d1.quantile(0.25)
q3=d1.quantile(0.75)
iqr=q3-q1
ul=q3+(1.5*iqr)
ll=q1-(1.5*iqr)
d2=d1[~(((d1>ul)|(d1<ll)).any(axis=1))]
d2.shape
# Out:
# (557, 77)

# %%
d1.shape
# Out:
# (1460, 77)

# %% [markdown]
# We can see that nearly 38% are outliers so we left it untreated

# %% [markdown]
# ## Data Visualisation

# %% [markdown]
# ### Univariate Analysis

# %%
d1.drop("Id",axis=1,inplace=True)

# %%
num=d1.select_dtypes(include=np.number).columns
num
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
num1=['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
       'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2','BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
       'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
       'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
       'GarageYrBlt']

# %%
figure,ax = plt.subplots(5,5 , figsize=(10,15))

for i,j in zip(num1,ax.flatten()):
    sns.distplot(x = d1[i] ,ax = j )
    subplot.set_title(i)

plt.tight_layout()
plt.show()

# %%
col=d1.select_dtypes(include='O').columns
col
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
col1=['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
       'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']

# %%
figure,ax = plt.subplots(5,5 , figsize=(10,15))

for i,j in zip(col1,ax.flatten()):
    sns.countplot(x = d1[i] , ax = j )
    subplot.set_title(i)
    plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Bivariant Analysis

# %%
figure,ax = plt.subplots(5,5 , figsize=(10,15))

for i,j in zip(num1,ax.flatten()):
    sns.scatterplot(x = d1[i] , y = d1["SalePrice"], ax = j )
    subplot.set_title(i)
plt.tight_layout()
plt.show()

# %%
figure,ax = plt.subplots(5,5 , figsize=(10,15))

for i,j in zip(col1,ax.flatten()):
    sns.barplot(x = d1[i] , y = d1["SalePrice"], ax = j )
    subplot.set_title(i)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Multivariant Analysis

# %%
plt.figure(figsize=[25,25])
sns.heatmap(d1.corr(),annot=True)
plt.show()

# %% [markdown]
# ### Skewness

# %%
d1.skew()
# Out:
# MSSubClass        1.407657
# LotFrontage       2.409147
# LotArea          12.207688
# OverallQual       0.216944
# OverallCond       0.693067
# YearBuilt        -0.613461
# YearRemodAdd     -0.503562
# MasVnrArea        2.677616
# BsmtFinSF1        1.685503
# BsmtFinSF2        4.255261
# BsmtUnfSF         0.920268
# TotalBsmtSF       1.524255
# 1stFlrSF          1.376757
# 2ndFlrSF          0.813030
# LowQualFinSF      9.011341
# GrLivArea         1.366560
# BsmtFullBath      0.596067
# BsmtHalfBath      4.103403
# FullBath          0.036562
# HalfBath          0.675897
# BedroomAbvGr      0.211790
# KitchenAbvGr      4.488397
# TotRmsAbvGrd      0.676341
# Fireplaces        0.649565
# GarageYrBlt      -0.678333
# GarageCars       -0.342549
# GarageArea        0.179981
# WoodDeckSF        1.541376
# OpenPorchSF       2.364342
# EnclosedPorch     3.089872
# 3SsnPorch        10.304342
# ScreenPorch       4.122214
# PoolArea         14.828374
# MiscVal          24.476794
# ...

# %% [markdown]
# To reduce the skewness, i am using transformtion techniques to reduce the skewness

# %%
d1.skew()[d1.skew()>2]
# Out:
# LotFrontage       2.409147
# LotArea          12.207688
# MasVnrArea        2.677616
# BsmtFinSF2        4.255261
# LowQualFinSF      9.011341
# BsmtHalfBath      4.103403
# KitchenAbvGr      4.488397
# OpenPorchSF       2.364342
# EnclosedPorch     3.089872
# 3SsnPorch        10.304342
# ScreenPorch       4.122214
# PoolArea         14.828374
# MiscVal          24.476794
# dtype: float64

# %% [markdown]
# ## Transformation

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pt=PowerTransformer()
d1[['LotFrontage','LotArea','MasVnrArea','BsmtFinSF2','LowQualFinSF','BsmtHalfBath','KitchenAbvGr','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','MiscVal']]=pt.fit_transform(d1[['LotFrontage','LotArea','MasVnrArea','BsmtFinSF2','LowQualFinSF','BsmtHalfBath','KitchenAbvGr','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','MiscVal']])

# %%
d1.skew()
# Out:
# MSSubClass        1.407657
# LotFrontage       0.167283
# LotArea           0.026569
# OverallQual       0.216944
# OverallCond       0.693067
# YearBuilt        -0.613461
# YearRemodAdd     -0.503562
# MasVnrArea        0.426258
# BsmtFinSF1        1.685503
# BsmtFinSF2        2.425650
# BsmtUnfSF         0.920268
# TotalBsmtSF       1.524255
# 1stFlrSF          1.376757
# 2ndFlrSF          0.813030
# LowQualFinSF      7.299413
# GrLivArea         1.366560
# BsmtFullBath      0.596067
# BsmtHalfBath      3.859402
# FullBath          0.036562
# HalfBath          0.675897
# BedroomAbvGr      0.211790
# KitchenAbvGr     -2.800950
# TotRmsAbvGrd      0.676341
# Fireplaces        0.649565
# GarageYrBlt      -0.678333
# GarageCars       -0.342549
# GarageArea        0.179981
# WoodDeckSF        1.541376
# OpenPorchSF      -0.014772
# EnclosedPorch     2.047941
# 3SsnPorch         7.613746
# ScreenPorch       3.113266
# PoolArea         14.352680
# MiscVal           5.016528
# ...

# %% [markdown]
# ### Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
col
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
le=LabelEncoder()
for i in col:
    d1[i]=le.fit_transform(d1[i])

# %% [markdown]
# Here all the categorical columns are encoded using label encoder

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Statistic model

# %% [markdown]
# ### Splitting the data

# %%
x=d1.drop("SalePrice",axis=1)
y=d1['SalePrice']

# %%
import statsmodels.api as sm
xc=sm.add_constant(x)

# %%
model=sm.OLS(y,xc).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.848
# Model:                            OLS   Adj. R-squared:                  0.839
# Method:                 Least Squares   F-statistic:                     102.7
# Date:                Fri, 09 Feb 2024   Prob (F-statistic):               0.00
# Time:                        19:43:09   Log-Likelihood:                -17170.
# No. Observations:                1460   AIC:                         3.449e+04
# Df Residuals:                    1384   BIC:                         3.489e+04
# Df Model:                          75
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.736e+06   1.33e+06      1.303      0.193   -8.77e+05    4.35e+06
# ...

# %% [markdown]
# ### Assumption 1: Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif

# %%
vf=[vif(xc.values,i) for i in range(xc.shape[1])]
a=pd.DataFrame(vf,index=xc.columns,columns=['vif'])
a.sort_values("vif",ascending=False)
# Out:
#                       vif
# const        2.556971e+06
# GrLivArea    6.390386e+02
# 2ndFlrSF     4.393730e+02
# 1stFlrSF     3.442285e+02
# TotalBsmtSF  2.672235e+01
# ...                   ...
# YrSold       1.099848e+00
# Utilities    1.099269e+00
# Condition2   1.086109e+00
# MoSold       1.075702e+00
# 3SsnPorch    1.069419e+00
#
# [76 rows x 1 columns]

# %%
x=d1.drop(columns=["SalePrice",'GrLivArea'],axis=1)
y=d1['SalePrice']

# %%
xc=sm.add_constant(x)

# %%
model=sm.OLS(y,xc).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.839
# Method:                 Least Squares   F-statistic:                     103.8
# Date:                Fri, 09 Feb 2024   Prob (F-statistic):               0.00
# Time:                        19:49:18   Log-Likelihood:                -17172.
# No. Observations:                1460   AIC:                         3.449e+04
# Df Residuals:                    1385   BIC:                         3.489e+04
# Df Model:                          74
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.706e+06   1.33e+06      1.279      0.201    -9.1e+05    4.32e+06
# ...

# %%
vf=[vif(xc.values,i) for i in range(xc.shape[1])]
a=pd.DataFrame(vf,index=xc.columns,columns=['vif'])
a.sort_values("vif",ascending=False)
# Out:
#                       vif
# const        2.556627e+06
# TotalBsmtSF  2.671739e+01
# BsmtFinSF1   2.567347e+01
# BsmtUnfSF    2.469833e+01
# YearBuilt    8.140607e+00
# ...                   ...
# YrSold       1.099733e+00
# Utilities    1.099244e+00
# Condition2   1.086047e+00
# MoSold       1.074416e+00
# 3SsnPorch    1.068017e+00
#
# [75 rows x 1 columns]

# %%
x=d1.drop(columns=["SalePrice",'GrLivArea','TotalBsmtSF'],axis=1)
y=d1['SalePrice']

# %%
xc=sm.add_constant(x)

# %%
model=sm.OLS(y,xc).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.839
# Method:                 Least Squares   F-statistic:                     105.1
# Date:                Fri, 09 Feb 2024   Prob (F-statistic):               0.00
# Time:                        19:51:09   Log-Likelihood:                -17174.
# No. Observations:                1460   AIC:                         3.450e+04
# Df Residuals:                    1386   BIC:                         3.489e+04
# Df Model:                          73
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           1.68e+06   1.33e+06      1.259      0.208   -9.37e+05     4.3e+06
# ...

# %%
vf=[vif(xc.values,i) for i in range(xc.shape[1])]
a=pd.DataFrame(vf,index=xc.columns,columns=['vif'])
a.sort_values("vif",ascending=False)
# Out:
#                      vif
# const       2.556211e+06
# YearBuilt   8.140485e+00
# 1stFlrSF    6.898340e+00
# 2ndFlrSF    6.240642e+00
# GarageCars  6.054396e+00
# ...                  ...
# YrSold      1.099477e+00
# Utilities   1.098427e+00
# Condition2  1.084036e+00
# MoSold      1.074378e+00
# 3SsnPorch   1.064926e+00
#
# [74 rows x 1 columns]

# %%
x=d1.drop(columns=["SalePrice",'GrLivArea','TotalBsmtSF','YearBuilt'],axis=1)
y=d1['SalePrice']
xc=sm.add_constant(x)
model=sm.OLS(y,xc).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.846
# Model:                            OLS   Adj. R-squared:                  0.838
# Method:                 Least Squares   F-statistic:                     106.0
# Date:                Fri, 09 Feb 2024   Prob (F-statistic):               0.00
# Time:                        19:52:43   Log-Likelihood:                -17177.
# No. Observations:                1460   AIC:                         3.450e+04
# Df Residuals:                    1387   BIC:                         3.489e+04
# Df Model:                          72
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          2.055e+06   1.33e+06      1.546      0.122   -5.52e+05    4.66e+06
# ...

# %%
vf=[vif(xc.values,i) for i in range(xc.shape[1])]
a=pd.DataFrame(vf,index=xc.columns,columns=['vif'])
a.sort_values("vif",ascending=False)
# Out:
#                      vif
# const       2.526311e+06
# 1stFlrSF    6.719837e+00
# 2ndFlrSF    6.016267e+00
# GarageCars  6.013885e+00
# GarageArea  5.966069e+00
# ...                  ...
# Utilities   1.098401e+00
# YrSold      1.097709e+00
# Condition2  1.075720e+00
# MoSold      1.073949e+00
# 3SsnPorch   1.064138e+00
#
# [73 rows x 1 columns]

# %%
x=d1.drop(columns=["SalePrice",'GrLivArea','TotalBsmtSF','YearBuilt','1stFlrSF'],axis=1)
y=d1['SalePrice']
xc=sm.add_constant(x)
model=sm.OLS(y,xc).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.839
# Model:                            OLS   Adj. R-squared:                  0.830
# Method:                 Least Squares   F-statistic:                     101.6
# Date:                Fri, 09 Feb 2024   Prob (F-statistic):               0.00
# Time:                        19:53:40   Log-Likelihood:                -17213.
# No. Observations:                1460   AIC:                         3.457e+04
# Df Residuals:                    1388   BIC:                         3.495e+04
# Df Model:                          71
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.916e+06   1.36e+06      1.408      0.159   -7.54e+05    4.59e+06
# ...

# %%
vf=[vif(xc.values,i) for i in range(xc.shape[1])]
a=pd.DataFrame(vf,index=xc.columns,columns=['vif'])
a.sort_values("vif",ascending=False)
# Out:
#                      vif
# const       2.525913e+06
# GarageCars  5.983913e+00
# GarageArea  5.809809e+00
# MSSubClass  5.143888e+00
# BldgType    4.824173e+00
# ...                  ...
# Utilities   1.098383e+00
# YrSold      1.097308e+00
# Condition2  1.075541e+00
# MoSold      1.073047e+00
# 3SsnPorch   1.063692e+00
#
# [72 rows x 1 columns]

# %%
x=d1.drop(columns=["SalePrice",'GrLivArea','TotalBsmtSF','YearBuilt','1stFlrSF','GarageCars'],axis=1)
y=d1['SalePrice']
xc=sm.add_constant(x)
model=sm.OLS(y,xc).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.829
# Method:                 Least Squares   F-statistic:                     102.1
# Date:                Fri, 09 Feb 2024   Prob (F-statistic):               0.00
# Time:                        19:55:18   Log-Likelihood:                -17218.
# No. Observations:                1460   AIC:                         3.458e+04
# Df Residuals:                    1389   BIC:                         3.495e+04
# Df Model:                          70
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          2.064e+06   1.37e+06      1.512      0.131   -6.14e+05    4.74e+06
# ...

# %%
x=d1.drop(columns=["SalePrice",'GrLivArea','TotalBsmtSF','YearBuilt','1stFlrSF','MSZoning','LotFrontage','LotShape','Utilities',
                  'LotConfig','Condition1','BldgType','YearRemodAdd','Exterior2nd','MasVnrType','MasVnrArea','ExterCond',
                  'BsmtFinType1','BsmtFinType2','BsmtFinSF2','Heating'],axis=1)
y=d1['SalePrice']
xc=sm.add_constant(x)
model=sm.OLS(y,xc).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.836
# Model:                            OLS   Adj. R-squared:                  0.830
# Method:                 Least Squares   F-statistic:                     130.4
# Date:                Fri, 09 Feb 2024   Prob (F-statistic):               0.00
# Time:                        20:02:08   Log-Likelihood:                -17223.
# No. Observations:                1460   AIC:                         3.456e+04
# Df Residuals:                    1404   BIC:                         3.485e+04
# Df Model:                          55
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.914e+06   1.36e+06      1.413      0.158   -7.44e+05    4.57e+06
# ...

# %%
x=d1.drop(columns=["SalePrice",'GrLivArea','TotalBsmtSF','YearBuilt','1stFlrSF','MSZoning','LotFrontage','LotShape','Utilities',
                  'LotConfig','Condition1','BldgType','YearRemodAdd','Exterior2nd','MasVnrType','MasVnrArea','ExterCond',
                  'BsmtFinType1','BsmtFinType2','BsmtFinSF2','Heating','LowQualFinSF','BsmtHalfBath','HalfBath','GarageType',
                  'GarageYrBlt','GarageFinish','GarageArea','GarageQual','GarageCond'],axis=1)
y=d1['SalePrice']
xc=sm.add_constant(x)
model=sm.OLS(y,xc).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.836
# Model:                            OLS   Adj. R-squared:                  0.830
# Method:                 Least Squares   F-statistic:                     156.2
# Date:                Fri, 09 Feb 2024   Prob (F-statistic):               0.00
# Time:                        20:05:56   Log-Likelihood:                -17226.
# No. Observations:                1460   AIC:                         3.455e+04
# Df Residuals:                    1413   BIC:                         3.479e+04
# Df Model:                          46
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           1.91e+06   1.35e+06      1.420      0.156   -7.29e+05    4.55e+06
# ...

# %%
x1=x.drop(columns=['HeatingQC','CentralAir','Electrical','OpenPorchSF','EnclosedPorch','PoolArea','MoSold','YrSold','SaleType'],axis=1)
y=d1['SalePrice']
x1c=sm.add_constant(x1)
model=sm.OLS(y,x1c).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.835
# Model:                            OLS   Adj. R-squared:                  0.830
# Method:                 Least Squares   F-statistic:                     193.9
# Date:                Fri, 09 Feb 2024   Prob (F-statistic):               0.00
# Time:                        20:10:03   Log-Likelihood:                -17231.
# No. Observations:                1460   AIC:                         3.454e+04
# Df Residuals:                    1422   BIC:                         3.474e+04
# Df Model:                          37
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -2.329e+04   2.05e+04     -1.136      0.256   -6.35e+04    1.69e+04
# ...

# %% [markdown]
# Even though all insignificant columns are removed there is still multicollinearity

# %% [markdown]
# ### Assumption 2:Normality

# %%
residuals=model.resid

# %%
sns.kdeplot(residuals)
plt.show()

# %%
from scipy import stats

# %%
print(stats.jarque_bera(residuals))
# Out:
# SignificanceResult(statistic=57340.793492613135, pvalue=0.0)

# %% [markdown]
# from the plot and p_value in the jarquebera test , we can tell that the residuals are normal

# %% [markdown]
# ### asssumption 3: Homoscedasticity of Residuals

# %%
residuals=model.resid
y_pred=model.predict(x1c)
plt.figure(figsize=(10,10))
sns.regplot(x=y_pred,y=residuals)
plt.show()

# %%
import statsmodels.stats.api as sms
sms.het_goldfeldquandt(y=model.resid,x=xc)
# Out:
# (1.1712052909541615, 0.019546077142966283, 'increasing')

# %% [markdown]
# from the plot and goldfeldquantd test we can tell that the residuals are not homoscedastic

# %% [markdown]
# ### Assumption 4: Auto-correlation of Residuals

# %%
residuals=model.resid
import statsmodels.tsa.api as smt

# %%
smt.graphics.plot_acf(residuals,lags=30)
plt.show()

# %%
from statsmodels.stats.stattools import durbin_watson
durbin_watson(residuals)
# Out:
# 1.9892366726781716

# %% [markdown]
# here there is no autocorrelation among the residuals

# %% [markdown]
# ### Assumption 5: Linearity

# %%
sm.stats.diagnostic.linear_rainbow(model)
# Out:
# (1.016995187509789, 0.41144284400074793)

# %% [markdown]
# the datas are linear

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x1,y,test_size=0.2,random_state=100)

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
lr=LinearRegression()
lr.fit(xtrain,ytrain)

y_pred_train=lr.predict(xtrain)
y_pred_test=lr.predict(xtest)

r2_train=r2_score(ytrain,y_pred_train)
r2_test=r2_score(ytest,y_pred_test)

train_mse=mean_squared_error(ytrain,y_pred_train)
test_mse=mean_squared_error(ytest,y_pred_test)

train_rmse=np.sqrt(train_mse)
test_rmse=np.sqrt(test_mse)

res_lr=[r2_train,r2_test,train_rmse,test_rmse]
res_lr
# Out:
# [0.8244286813644748, 0.8674194102051855, 33194.043991945786, 29195.42030624342]

# %%
results_1=pd.DataFrame()
results_1.index = [' R2 Train','R2 Test','RMSE Train', 'RMSE Test']

# %%
results_1['Base model']=res_lr
results_1.T
# Out:
#              R2 Train   R2 Test    RMSE Train     RMSE Test
# Base model   0.824429  0.867419  33194.043992  29195.420306

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)
rf_regressor.fit(xtrain, ytrain)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = rf_regressor.predict(xtest)

# %%
y_pred_train=rf_regressor.predict(xtrain)

# %%
r2_train=r2_score(ytrain,y_pred_train)
r2_test=r2_score(ytest,y_pred)

train_mse=mean_squared_error(ytrain,y_pred_train)
test_mse=mean_squared_error(ytest,y_pred)

train_rmse=np.sqrt(train_mse)
test_rmse=np.sqrt(test_mse)

res_r=[r2_train,r2_test,train_rmse,test_rmse]
res_r
# Out:
# [0.9784656370612744, 0.8761899682641563, 11625.172180103316, 28213.22133748002]

# %%
results_1['Random Forest Regreesor model']=res_r
results_1.T
# Out:
#                                 R2 Train   R2 Test    RMSE Train     RMSE Test
# Base model                      0.824429  0.867419  33194.043992  29195.420306
# Random Forest Regreesor model   0.978466  0.876190  11625.172180  28213.221337

# %%
feature_importances = rf_regressor.feature_importances_
plt.bar(range(len(feature_importances)), feature_importances)
plt.xlabel('Feature')
plt.ylabel('Importance')
plt.title('Feature Importances')
plt.show()

# %% [markdown]
# comapring with base model Random Forest Regressor model performs well.So i am fixing Random Forest Regressor Model as my final model for predicting the house price
